# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # LinearRegression

# %% [markdown]
# # PH01-00

# %%
#read the data from the excel file
df = pd.read_excel('NEW_Ph0100(preprocessed_smooth_5).xlsx')
# Select only the columns that we want to use: Pressure_ground_truth, Pressure, and Flowrate
df = df[['Pressure', 'Flowrate','Pressure_ground_truth']]

df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# Dropping any rows with Nan values
df_binary.dropna(inplace = True)  

score = []
rmse = []

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# k-fold validation
for i in range(1, 11): 

    # Select the test set
    X_test = X_split[i-1]
    y_test = y_split[i-1]

    # Select the training set
    X_train = np.concatenate(X_split[:i-1] + X_split[i:], axis=0)
    y_train = np.concatenate(y_split[:i-1] + y_split[i:], axis=0)

    # Drop NaN values from X_train and y_train, X_test and y_test
    X_train = X_train[~np.isnan(X_train).any(axis=1)]
    y_train = y_train[~np.isnan(y_train).any(axis=1)]
    X_test = X_test[~np.isnan(X_test).any(axis=1)]
    y_test = y_test[~np.isnan(y_test).any(axis=1)]

    # create a linear regression model
    model = LinearRegression()
    model.fit(X_train, y_train)

    score.append(model.score(X_test, y_test))
    rmse.append(np.sqrt(mean_squared_error(y_test, model.predict(X_test))))

# print the average score and rmse
print("Score: ", np.mean(score))
print("RMSE: ", np.mean(rmse))

# %% [markdown]
# # PH03-02

# %%
#read the data from the excel file
df = pd.read_excel('NEW_Ph0302(preprocessed_smooth_5_temp).xlsx')

df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# Dropping any rows with Nan values  
df_binary.dropna(inplace = True)

score = []
rmse = []

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# k-fold validation
for i in range(1, 11): 

    # Select the test set
    X_test = X_split[i-1]
    y_test = y_split[i-1]

    # Select the training set
    X_train = np.concatenate(X_split[:i-1] + X_split[i:], axis=0)
    y_train = np.concatenate(y_split[:i-1] + y_split[i:], axis=0)

    # Drop NaN values from X_train and y_train, X_test and y_test
    X_train = X_train[~np.isnan(X_train).any(axis=1)]
    y_train = y_train[~np.isnan(y_train).any(axis=1)]
    X_test = X_test[~np.isnan(X_test).any(axis=1)]
    y_test = y_test[~np.isnan(y_test).any(axis=1)]

    # create a linear regression model
    model = LinearRegression()
    model.fit(X_train, y_train)

    score.append(model.score(X_test, y_test))
    rmse.append(np.sqrt(mean_squared_error(y_test, model.predict(X_test))))

# print the average score and rmse
print("Score: ", np.mean(score))
print("RMSE: ", np.mean(rmse))
# Out:
# Score:  0.8942461831449128
# RMSE:  0.6616487845998057

# %% [markdown]
# # PH03-03

# %%
#read the data from the excel file
df = pd.read_excel('NEW_Ph0303(preprocessed_smooth_5).xlsx')

df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# Dropping any rows with Nan values  
df_binary.dropna(inplace = True)

score = []
rmse = []

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# k-fold validation
for i in range(1, 11): 

    # Select the test set
    X_test = X_split[i-1]
    y_test = y_split[i-1]

    # Select the training set
    X_train = np.concatenate(X_split[:i-1] + X_split[i:], axis=0)
    y_train = np.concatenate(y_split[:i-1] + y_split[i:], axis=0) 

    # Drop NaN values from X_train and y_train, X_test and y_test
    X_train = X_train[~np.isnan(X_train).any(axis=1)]
    y_train = y_train[~np.isnan(y_train).any(axis=1)]
    X_test = X_test[~np.isnan(X_test).any(axis=1)]
    y_test = y_test[~np.isnan(y_test).any(axis=1)]

    # create a linear regression model
    model = LinearRegression()
    model.fit(X_train, y_train)

    score.append(model.score(X_test, y_test))
    rmse.append(np.sqrt(mean_squared_error(y_test, model.predict(X_test))))

# print the average score and rmse
print("Score: ", np.mean(score))
print("RMSE: ", np.mean(rmse))

# %% [markdown]
# # SVM
# # PH01-00

# %%
# Reading the dataset
df = pd.read_excel('NEW_Ph0100(preprocessed_smooth_5).xlsx')
df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# Dropping any rows with Nan values  
df_binary.dropna(inplace = True)

score = []
rmse = []

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# k-fold validation
for i in range(1, 11): 

    # Select the test set
    X_test = X_split[i-1]
    y_test = y_split[i-1]

    # Select the training set
    X_train = np.concatenate(X_split[:i-1] + X_split[i:], axis=0)
    y_train = np.concatenate(y_split[:i-1] + y_split[i:], axis=0)

    # Drop NaN values from X_train and y_train, X_test and y_test
    X_train = X_train[~np.isnan(X_train).any(axis=1)]
    y_train = y_train[~np.isnan(y_train).any(axis=1)]
    X_test = X_test[~np.isnan(X_test).any(axis=1)]
    y_test = y_test[~np.isnan(y_test).any(axis=1)]

    # create a linear regression model
    # Fitting the Regression Model to the dataset
    from sklearn.svm import SVR
    regressor = SVR(kernel = 'rbf')
    regressor.fit(X_train, y_train)

    # predicting the test set results
    y_pred = regressor.predict(X_test)
    y_pred = y_pred.reshape(-1, 1)

    score.append(regressor.score(X_test, y_test))
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))

# print the average score and rmse
print("Score: ", np.mean(score))
print("RMSE: ", np.mean(rmse))

# %% [markdown]
# # PH03-02

# %%
# Reading the dataset
df = pd.read_excel('NEW_Ph0302(preprocessed_smooth_5).xlsx')
df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# Dropping any rows with Nan values  
df_binary.dropna(inplace = True)

score = []
rmse = []

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# k-fold validation
for i in range(1, 11): 

    # Select the test set
    X_test = X_split[i-1]
    y_test = y_split[i-1]

    # Select the training set
    X_train = np.concatenate(X_split[:i-1] + X_split[i:], axis=0)
    y_train = np.concatenate(y_split[:i-1] + y_split[i:], axis=0)

    # Drop NaN values from X_train and y_train, X_test and y_test
    X_train = X_train[~np.isnan(X_train).any(axis=1)]
    y_train = y_train[~np.isnan(y_train).any(axis=1)]
    X_test = X_test[~np.isnan(X_test).any(axis=1)]
    y_test = y_test[~np.isnan(y_test).any(axis=1)]

    # create a linear regression model
    # Fitting the Regression Model to the dataset
    from sklearn.svm import SVR
    regressor = SVR(kernel = 'rbf')
    regressor.fit(X_train, y_train)

    # predicting the test set results
    y_pred = regressor.predict(X_test)
    y_pred = y_pred.reshape(-1, 1)

    score.append(regressor.score(X_test, y_test))
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))

# print the average score and rmse
print("Score: ", np.mean(score))
print("RMSE: ", np.mean(rmse))

# %% [markdown]
# # PH03-03

# %%
# Reading the dataset
df = pd.read_excel('NEW_Ph0303(preprocessed_smooth_5).xlsx')
df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# Dropping any rows with Nan values  
df_binary.dropna(inplace = True)

score = []
rmse = []

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# k-fold validation
for i in range(1, 11): 

    # Select the test set
    X_test = X_split[i-1]
    y_test = y_split[i-1]

    # Select the training set
    X_train = np.concatenate(X_split[:i-1] + X_split[i:], axis=0)
    y_train = np.concatenate(y_split[:i-1] + y_split[i:], axis=0)

    # Drop NaN values from X_train and y_train, X_test and y_test
    X_train = X_train[~np.isnan(X_train).any(axis=1)]
    y_train = y_train[~np.isnan(y_train).any(axis=1)]
    X_test = X_test[~np.isnan(X_test).any(axis=1)]
    y_test = y_test[~np.isnan(y_test).any(axis=1)]

    # create a linear regression model
    # Fitting the Regression Model to the dataset
    from sklearn.svm import SVR
    regressor = SVR(kernel = 'rbf')
    regressor.fit(X_train, y_train)

    # predicting the test set results
    y_pred = regressor.predict(X_test)
    y_pred = y_pred.reshape(-1, 1)

    score.append(regressor.score(X_test, y_test))
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))

# print the average score and rmse
print("Score: ", np.mean(score))
print("RMSE: ", np.mean(rmse))

# %%
# Reading the dataset
#read the data from the excel file
df = pd.read_excel('/content/Ph0100(preprocessed_smooth_5).xlsx')
# Select only the columns that we want to use: Pressure_ground_truth, Pressure, and Flowrate
df = df[['Pressure', 'Flowrate','Pressure_ground_truth']]

df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# remove NaN values
df_binary.dropna(inplace = True)

score = []
rmse = []

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# k-fold validation
for i in range(1, 11): 

    # Select the test set
    X_test = X_split[i-1]
    y_test = y_split[i-1]

    # Select the training set
    X_train = np.concatenate(X_split[:i-1] + X_split[i:], axis=0)
    y_train = np.concatenate(y_split[:i-1] + y_split[i:], axis=0)

    # Drop NaN values from X_train and y_train, X_test and y_test
    X_train = X_train[~np.isnan(X_train).any(axis=1)]
    y_train = y_train[~np.isnan(y_train).any(axis=1)]
    X_test = X_test[~np.isnan(X_test).any(axis=1)]
    y_test = y_test[~np.isnan(y_test).any(axis=1)]

    # CNN
    model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[1]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
    ])

    model.compile(
    optimizer='adam',
    loss='mean_absolute_error',
    metrics=['mean_absolute_error', 'mean_squared_error'])

    history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=32,
    epochs=100)

    # Predictions
    y_pred = model.predict(X_test).flatten()

    score.append(model.evaluate(X_test, y_test)[1])
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
# Plot one LR, SVR, and CNN model in the same graph for each dataset 

# Reading the dataset
df = pd.read_excel('/content/NEW_Ph0100(preprocessed_smooth_5).xlsx')
df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# Dropping any rows with Nan values
df_binary.dropna(inplace = True)

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# Select the test set
X_test = X_split[0]
y_test = y_split[0]

# Select the training set
X_train = np.concatenate(X_split[:0] + X_split[1:], axis=0)
y_train = np.concatenate(y_split[:0] + y_split[1:], axis=0)

# Drop NaN values from X_train and y_train, X_test and y_test
X_train = X_train[~np.isnan(X_train).any(axis=1)]
y_train = y_train[~np.isnan(y_train).any(axis=1)]
X_test = X_test[~np.isnan(X_test).any(axis=1)]
y_test = y_test[~np.isnan(y_test).any(axis=1)]

# create a linear regression model
# Fitting the Regression Model to the dataset
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
regressor1.fit(X_train, y_train)

# predicting the test set results
y_pred1 = regressor1.predict(X_test)
y_pred1 = y_pred1.reshape(-1, 1)

# create a SVR model
# Fitting the SVR Model to the dataset
from sklearn.svm import SVR
regressor2 = SVR(kernel = 'rbf')
regressor2.fit(X_train, y_train)

# predicting the test set results
y_pred2 = regressor2.predict(X_test)
y_pred2 = y_pred2.reshape(-1, 1)

# CNN
model = keras.Sequential([
layers.Dense(64, activation='relu', input_shape=[1]),
layers.Dense(64, activation='relu'),
layers.Dense(1)
])

model.compile(
optimizer='adam',
loss='mean_absolute_error',
metrics=['mean_absolute_error', 'mean_squared_error'])

history = model.fit(
X_train, y_train,
validation_data=(X_test, y_test),
batch_size=32,
epochs=100)

# Predictions
y_pred3 = model.predict(X_test).flatten()

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color = 'dodgerblue', label = 'Training data')
plt.scatter(X_test, y_test, color = 'lightblue', label = 'Test data')
plt.plot(X_test, y_pred1, color = 'black', label = 'LR', linewidth = 2, markersize = 6)
plt.scatter(X_test, y_pred2, color = 'red', label = 'SVR', marker = '+', linewidth = 2)
plt.scatter(X_test, y_pred3, color = 'green', label = 'CNN', marker = '*', linewidth = 2)
plt.title('Flowrate vs Pressure')
plt.xlabel('Pressure')
plt.ylabel('Flowrate')
plt.legend()

# %%
# Plot one LR, SVR, and CNN model in the same graph for each dataset 

# Reading the dataset
df = pd.read_excel('/content/NEW_Ph0303(preprocessed_smooth_5).xlsx')
df_binary = df[['Flowrate', 'Pressure']]
df_binary = df_binary.sample(frac=1)

X = np.array(df_binary['Pressure']).reshape(-1, 1)
y = np.array(df_binary['Flowrate']).reshape(-1, 1)

# Dropping any rows with Nan values
df_binary.dropna(inplace = True)

# Split the data into 10 sets for k-fold validation
X_split = np.array_split(X, 10)
y_split = np.array_split(y, 10)

# Select the test set
X_test = X_split[0]
y_test = y_split[0]

# Select the training set
X_train = np.concatenate(X_split[:0] + X_split[1:], axis=0)
y_train = np.concatenate(y_split[:0] + y_split[1:], axis=0)

# Drop NaN values from X_train and y_train, X_test and y_test
X_train = X_train[~np.isnan(X_train).any(axis=1)]
y_train = y_train[~np.isnan(y_train).any(axis=1)]
X_test = X_test[~np.isnan(X_test).any(axis=1)]
y_test = y_test[~np.isnan(y_test).any(axis=1)]

# create a linear regression model
# Fitting the Regression Model to the dataset
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
regressor1.fit(X_train, y_train)

# predicting the test set results
y_pred1 = regressor1.predict(X_test)
y_pred1 = y_pred1.reshape(-1, 1)

# create a SVR model
# Fitting the SVR Model to the dataset
from sklearn.svm import SVR
regressor2 = SVR(kernel = 'rbf')
regressor2.fit(X_train, y_train)

# predicting the test set results
y_pred2 = regressor2.predict(X_test)
y_pred2 = y_pred2.reshape(-1, 1)

# CNN
model = keras.Sequential([
layers.Dense(64, activation='relu', input_shape=[1]),
layers.Dense(64, activation='relu'),
layers.Dense(1)
])

model.compile(
optimizer='adam',
loss='mean_absolute_error',
metrics=['mean_absolute_error', 'mean_squared_error'])

history = model.fit(
X_train, y_train,
validation_data=(X_test, y_test),
batch_size=32,
epochs=100)

# Predictions
y_pred3 = model.predict(X_test).flatten()

df_sort = pd.DataFrame()
df_sort["W"] = X_test.flatten()
df_sort["X"] = y_pred1.flatten()
df_sort["Y"] = y_pred2.flatten()
df_sort["Z"] = y_pred3.flatten()
df_sort.sort_values(by="X", inplace=True)

X_test_new = list(df_sort["W"])
y_pred1_new = list(df_sort["X"])
y_pred2_new = list(df_sort["Y"])
y_pred3_new = list(df_sort["Z"])

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color = 'dodgerblue', label = 'Training data', marker = '.')
plt.scatter(X_test, y_test, color = 'blueviolet', label = 'Test data', marker = '+')
plt.plot(X_test_new, y_pred1_new, color = 'black', label = 'LR', linewidth = 4)
plt.plot(X_test_new, y_pred2_new, color = 'red', label = 'SVR', linestyle="dashdot", linewidth = 4)
plt.plot(X_test_new, y_pred3_new, color = 'lime', label = 'CNN', linestyle="densely dotted", linewidth = 4)
plt.xlabel('Pressure', fontsize=24)
plt.ylabel('Flowrate', fontsize=24)
plt.xlim(-0.1, 3)
plt.ylim(-0.5, 12)
plt.legend(loc = 2)
